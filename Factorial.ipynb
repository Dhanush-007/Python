# %% [markdown]
# <a href="https://colab.research.google.com/github/Dhanush-007/Python/blob/main/Factorial.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
fact=1
x=int(input("Enter a Positive number:"))

if (x<0):
  inpu=int(input("Enter a Positive number:"))
else:
  for i in range(1,x+1):
    fact=fact*i
  print(fact)
# Out:
# Enter a Positive number:5
# 120

# %% [markdown]
# ![Factorial Question .jpg](data:image/jpeg;base64,...)
